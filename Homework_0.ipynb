# %% [markdown]
# # <font style="color:black">Lecture 1: Homework Problem</font>
#
# In this first homework set, I want you to make sure that you can use GitHub, MS Code, and OpenCV.
# You should (already to be able to read this document), clone the Github classroom assignment and edit it in VS Code.  In this python notebook, do the following:
#
# * Load an (Grayscale) image  (‘Data/Apollo_11_Launch.jpg’)
# * View image
# * Crop image
# * Edit brightness of image
# * Rotate image
# * Save modified image

# %%
import cv2

import os
import numpy as numpy

import matplotlib.pyplot as plt

#loading in the greyscale image of Apollo 11 with funciton imread
greyscale_Apollo_11 = cv2.imread(os.path.relpath('Data/Apollo_11_Launch.jpg'),cv2.IMREAD_GRAYSCALE)

#viewing image using function imshow and color map is set to grey scale
plt.imshow(greyscale_Apollo_11, cmap="grey")

#cropping to show the object closely
new_greyscale_Apollo_11 = greyscale_Apollo_11[50:650,400:850]

#show the new cropped image
plt.imshow(new_greyscale_Apollo_11, cmap="grey")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 20
#      17 #show the new cropped image
#      18 plt.imshow(new_greyscale_Apollo_11, cmap="grey")
# ---> 20 matrix = np.ones(new_greyscale_Apollo_11.shape, dtype="uint8")*50
#
# NameError: name 'np' is not defined
